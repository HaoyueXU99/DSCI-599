# %% [markdown]
# # Importing libraries and loading data

# %% [markdown]
# # Coursera 2023 EDA
#
# Author: Yuheng Chen

# %%
# !pip install -q feature_engine autoviz>=0.1.803 dataprep 2>/dev/null

# %%
# !pip install autoviz
# Out:
# ...
#   Using cached autoviz-0.1.808-py3-none-any.whl (68 kB)
# ...
#   Using cached emoji-2.11.0-py2.py3-none-any.whl (433 kB)
# ...
#   Using cached holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# ...
#   Using cached hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
# ...
#   Using cached numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#   Using cached pandas_dq-1.29-py3-none-any.whl (29 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 19.6 MB/s eta 0:00:00
# ...
#   Using cached panel-0.14.4-py2.py3-none-any.whl (20.8 MB)
# ...
#   Using cached param-1.13.0-py2.py3-none-any.whl (87 kB)
# ...
#   Using cached pyamg-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
# ...
#   Using cached xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
# ...
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# ...
#   Attempting uninstall: param
#     Found existing installation: param 2.1.0
#     Uninstalling param-2.1.0:
#       Successfully uninstalled param-2.1.0
# ...

# %%
# !pip install dataprep
# Out:
# ...
#   Using cached dataprep-0.4.5-py3-none-any.whl (9.9 MB)
# ...
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# ...
#   Using cached jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# ...
#   Using cached Metaphone-0.6.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 59.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.0/764.0 kB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 40.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.1 MB/s eta 0:00:00
# ...

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 7.2 MB/s eta 0:00:00
# ...

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 6.3 MB/s eta 0:00:00
# ...

# %%
# !pip install feature_engine
# Out:
# ...
#   Using cached feature_engine-1.7.0-py2.py3-none-any.whl (344 kB)
# ...
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# ...
#   Using cached scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoviz 0.1.808 requires pandas<2.0, but you have pandas 2.2.2 which is incompatible.
# bigframes 1.2.0 requires sqlalchemy<3.0dev,>=1.4, but you have sqlalchemy 1.3.24 which is incompatible.
# ...

# %%
# Import necessary libraries
import numpy as np  # Import NumPy for handling numerical operations
import pandas as pd  # Import Pandas for data manipulation and analysis
import warnings  # Import Warnings to suppress unnecessary warnings

# Suppress warning messages
warnings.filterwarnings("ignore")


from autoviz import AutoViz_Class


from dataprep.datasets import load_dataset
from dataprep.eda import create_report

import shap

import matplotlib.pyplot as plt


from catboost import Pool, CatBoostRegressor

from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

from feature_engine.encoding import RareLabelEncoder


from sklearn.feature_extraction.text import CountVectorizer


import ast
import re

pd.set_option('display.max_rows', 1000)
# Out:
# Imported v0.1.808. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
# %%time
df = pd.read_csv('coursera_course_2024.csv', index_col=0) # Reads the dataset from a CSV file into a Pandas DataFrame
item0 = df.shape[0]
df = df.drop_duplicates()
item1 = df.shape[0]
print(f"There are {item0-item1} duplicates found in the dataset")

# Remove records with null label
df = df[~df['Ratings'].isnull()]


selected_cols = ['Ratings', 'Organization', 'Skills', 'Difficulty', 'Type', 'Duration']
df = df[selected_cols]

print(df.shape)  # Prints the dimensions (rows and columns) of the filtered DataFrame
df.sample(5).T  # Displays a random sample of 5 rows transposed for better visibility
# Out:
# There are 0 duplicates found in the dataset
# (623, 6)
# CPU times: user 25.3 ms, sys: 4.05 ms, total: 29.4 ms
# Wall time: 31 ms
#                                                                                                                                                                                                                                                                                                      4                                                                                                                                                                                                                                                                                            \
# ...

# %%
df.columns
# Out:
# Index(['Ratings', 'Organization', 'Skills', 'Difficulty', 'Type', 'Duration'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 623 entries, 0 to 628
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ratings       623 non-null    float64
#  1   Organization  623 non-null    object
#  2   Skills        623 non-null    object
#  3   Difficulty    623 non-null    object
#  4   Type          623 non-null    object
#  5   Duration      623 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 34.1+ KB

# %%
df.nunique()
# Out:
# Ratings          15
# Organization    115
# Skills          601
# Difficulty        4
# Type              5
# Duration          4
# dtype: int64

# %%
df.describe().T
# Out:
#          count    mean       std    min  25%  50%  75%  max
# Ratings  623.0  4.640931  0.195883  2.8  4.6  4.7  4.8  5.0

# %% [markdown]
# # Data transformation

# %%
df.columns
# Out:
# Index(['Ratings', 'Organization', 'Skills', 'Difficulty', 'Type', 'Duration'], dtype='object')

# %%
df.sample(5).T
# Out:
#                         484             \
# Ratings                            4.4
# Organization  Coursera Project Network
# Skills                 Cloud Computing
# Difficulty                    Beginner
# Type                    Guided Project
# Duration             Less Than 2 Hours
#
#                                                   84                                        \
# Ratings                                                                                4.8
# Organization                                                                        Google
# Skills         User Experience, User Experience Design, User Research, Product Development
# Difficulty                                                                        Beginner
# Type                                                                                Course
# Duration                                                                       1 - 4 Weeks
#
# ...

# %%
# %%time

# Select the main label.
main_label = 'Ratings'

# vectorize columns
def vectorize_column(df, col_name, min_df=20):
    try:
        df[col_name] = df[col_name].apply(ast.literal_eval)
        df[col_name] = df[col_name].apply(lambda x: ', '.join(list(set(x))))
    except:
        pass
    ll = df[col_name].fillna('none').str.split(',').to_list()
    ll = [[j.rstrip(',').strip(' ').replace('(', '_').replace(')', '_').replace(':', '_').replace('/', '_').replace('.', '_').replace('+', '_').replace(',', '_').replace('\'', '_').replace(' ', '_').replace('.', '_').replace('&', '_').replace('-', '_').replace('!', '_') for j in i] for i in ll]
    ll1 = []
    for item in ll:
        if item != ['none']:
            ttt = ' '.join(item)
        else:
            ttt = 'none'
        ll1.append(ttt)
    vectorizer = CountVectorizer(max_features=120, min_df=min_df, lowercase=False)
    vectorizer.fit(ll1)
    voc = vectorizer.vocabulary_
    voc_inv = {v: col_name+'_'+k for k, v in voc.items()}
    vector = vectorizer.transform(ll1)
    tt = pd.DataFrame(vector.toarray())
    tt = tt.rename(columns=voc_inv)
    df = pd.concat([df.reset_index(drop=True),tt.reset_index(drop=True)], axis=1).drop([col_name], axis=1)
    return df
for col in ['Skills']:
    df = vectorize_column(df, col_name=col, min_df=10)


# Set up a rare label encoder for selected columns.
for col in ['Organization', 'Difficulty', 'Type', 'Duration']:
    df[col] = df[col].fillna('None').astype(str)
    encoder = RareLabelEncoder(n_categories=1, max_n_categories=120, replace_with='Other', tol=10.0 / df.shape[0])
    df[col] = encoder.fit_transform(df[[col]])

print(df.shape)  # Print the shape of the resulting DataFrame.
df.sample(10).T  # Display a sample of 10 rows, transposed for easier readability.
# Out:
# (623, 125)
# CPU times: user 71.3 ms, sys: 3.14 ms, total: 74.4 ms
# Wall time: 88.9 ms
#                                                          537              \
# Ratings                                                              4.6
# Organization                                  University of Pennsylvania
# Difficulty                                                      Beginner
# Type                                                      Specialization
# Duration                                                    3 - 6 Months
# Skills_Accounting                                                      0
# Skills_Agile_Software_Development                                      0
# Skills_Algorithms                                                      1
# Skills_Application_Development                                         0
# Skills_Applied_Machine_Learning                                        1
# Skills_Artificial_Neural_Networks                                      0
# ...

# %% [markdown]
# # Machine learning

# %%
# Initialize data
# Extract the values of the 'main_label' column and reshape it into a 1D array as 'y'
y = df[main_label].values.reshape(-1,)

# Create the feature matrix 'X' by dropping the 'main_label' column from the DataFrame 'df'
X = df.drop([main_label], axis=1)


cat_cols = df.select_dtypes(include=['object']).columns


cat_cols_idx = [list(X.columns).index(c) for c in cat_cols]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0, stratify=df[['Organization']])

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (311, 124) (312, 124) (311,) (312,)

# %%
# %%time

# Initialize the training and testing data pools using CatBoost's Pool class
train_pool = Pool(X_train,
                  y_train,
                  cat_features=cat_cols_idx)  # Create a training data pool with categorical features
test_pool = Pool(X_test,
                 y_test,
                 cat_features=cat_cols_idx)  # Create a testing data pool with categorical features

# Specify the training parameters for the CatBoostRegressor model
model = CatBoostRegressor(iterations=500,    # Number of boosting iterations
                          depth=9,           # Maximum depth of trees in the ensemble
                          verbose=0,         # Set verbosity level to 0 (no output during training)
                          learning_rate=0.06,  # Learning rate for gradient boosting
                          early_stopping_rounds=30, # Early stopping rounds
                          loss_function='RMSE')  # Loss function to optimize (Root Mean Squared Error)

# Train the CatBoostRegressor model on the training data
model.fit(train_pool, eval_set=test_pool)

# Make predictions using the trained model on both the training and testing data
y_train_pred = model.predict(train_pool)
y_test_pred = model.predict(test_pool)

# Calculate and print the Root Mean Squared Error (RMSE) scores for training and testing data
rmse_train = mean_squared_error(y_train, y_train_pred, squared=False)  # RMSE for training data
rmse_test = mean_squared_error(y_test, y_test_pred, squared=False)     # RMSE for testing data

# Print the rounded RMSE scores
print(f"RMSE score for train {round(rmse_train, 3)} points, and for test {round(rmse_test, 3)} points")
# Out:
# RMSE score for train 0.181 points, and for test 0.153 points
# CPU times: user 4.45 s, sys: 732 ms, total: 5.18 s
# Wall time: 4.01 s

# %%
# Calculate the baseline RMSE (Root Mean Squared Error) scores for the training and test datasets.

# For the training dataset:


rmse_bs_train = mean_squared_error(y_train, [np.mean(y_train)]*len(y_train), squared=False)

# For the test dataset:

rmse_bs_test = mean_squared_error(y_test, [np.mean(y_train)]*len(y_test), squared=False)

# Print the rounded baseline RMSE scores for both the training and test datasets.
print(f"RMSE baseline score for train {round(rmse_bs_train, 3)} points, and for test {round(rmse_bs_test, 3)} points")
# Out:
# RMSE baseline score for train 0.223 points, and for test 0.164 points

# %% [markdown]
# # Explanations with SHAP values

# %%
# %matplotlib inline

# %%
# Calculate the expected values using a variable named 'ex.expected_value'.
expected_values = ex.expected_value

# Print the average predicted label
print(f"Average predicted rating is {round(expected_values, 3)} points")

# Print the average actual label from 'y_test'
print(f"Average actual rating is {round(np.mean(y_test), 3)} points")
# Out:
# Average predicted rating is 4.642 points
# Average actual rating is 4.643 points

# %%
# %%time
# Initialize the SHAP library for visualization
shap.initjs()

ex = shap.TreeExplainer(model)

# Calculate SHAP values for the 'X_test' data using the TreeExplainer
shap_values = ex.shap_values(X_test)

# Generate a summary plot to visualize the impact of features on model predictions
shap.summary_plot(shap_values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Define a function to show SHAP values for a specific column
def show_shap0(col):
    # Create a copy of the test data
    df_infl = X_test.copy()

    # Calculate the SHAP values for the specified column
    df_infl['shap_'] = shap_values[:, X_test.columns.tolist().index(col)]

    # Initialize variables for gain and gain_std
    gain = 0

    # Calculate the gain by taking the mean difference between values with and without the column
    gain = df_infl.groupby(col).mean().loc[1, 'shap_'] - df_infl.groupby(col).mean().loc[0, 'shap_']

    # Calculate gain_std by combining standard deviations of values with and without the column
    gain_std = ((df_infl.groupby(col).std().loc[1, 'shap_'])**2 + (df_infl.groupby(col).std().loc[0, 'shap_'])**2)**0.5

    # Return the gain and gain_std, rounded to 4 decimal places
    return round(gain, 4), round(gain_std, 4)

# Define a function to show SHAP values for columns starting with a given string
def show_variants(start_str):
    # Initialize lists to store column names, gains, and gain_stds
    col_list = []
    gain_list = []
    gain_std_list = []

    # Iterate through columns in X_test
    for col in X_test.columns:
        # Check if the column name starts with the specified string
        if col.startswith(start_str + '_'):
            try:
                # Call show_shap0 function to calculate gain and gain_std
                gain, gain_std = show_shap0(col)

                # Append column name, gain, and gain_std to respective lists
                col_list.append(col.replace(start_str + '_', ''))
                gain_list.append(gain)
                gain_std_list.append(gain_std)
            except:
                pass

    # Create a dictionary from the lists
    dd_dict = {'col': col_list, 'gain': gain_list, 'gain_std': gain_std_list}

    # Create a DataFrame from the dictionary, sort by gain in descending order, and set column 'col' as index
    df_res = pd.DataFrame.from_dict(dd_dict).sort_values('gain', ascending=False).set_index('col')

    # Create a bar chart with error bars to visualize SHAP values
    plt.figure(figsize=(24, 16))
    plt.errorbar(df_res.index, df_res['gain'], yerr=df_res['gain_std'], fmt="o", color="r")
    plt.bar(x=df_res.index, height=df_res['gain'])
    plt.title(f'SHAP values for {start_str}')
    plt.ylabel('points')
    plt.tick_params(axis="x", rotation=90)
    plt.show()

    # Return the DataFrame with results
    return df_res

# %%
show_variants(start_str='Skills')
# Out:
#                                         gain   gain_std
# col
# Human_Learning                         0.0089   0.0022
# Organizational_Development             0.0072   0.0022
# Writing                                0.0063   0.0025
# Cyberattacks                           0.0060   0.0021
# Strategy                               0.0055   0.0015
# Network_Architecture                   0.0051   0.0022
# Agile_Software_Development             0.0049   0.0020
# Spreadsheet_Software                   0.0048   0.0010
# Process_Analysis                       0.0044   0.0006
# Planning                               0.0039   0.0016
# Deep_Learning                          0.0039   0.0008
# Communication                          0.0038   0.0009
# Risk_Management                        0.0038   0.0014
# Leadership_and_Management              0.0036   0.0010
# Artificial_Neural_Networks             0.0034   0.0054
# Natural_Language_Processing            0.0034   0.0011
# ...

# %%
# Define a function named 'show_shap' that visualizes SHAP values for a specific feature.
# Parameters:
#   - col: The name of the feature for which SHAP values will be visualized.
#   - shap_values: SHAP values calculated for the model's predictions.
#   - label: The label to be displayed in the plot title.
#   - X_test: The DataFrame containing the test data.
#   - ylabel: The label for the y-axis in the plot (default is 'points').
def show_shap(col, shap_values=shap_values, label=main_label, X_test=X_test, ylabel='points'):
    # Create a copy of the test data DataFrame.
    df_infl = X_test.copy()

    # Add a new column 'shap_' to the DataFrame containing SHAP values for the specified feature.
    df_infl['shap_'] = shap_values[:, df_infl.columns.tolist().index(col)]

    # Calculate the mean SHAP values and standard deviation grouped by the specified feature.
    gain = round(df_infl.groupby(col)['shap_'].mean(), 4)
    gain_std = round(df_infl.groupby(col)['shap_'].std(), 4)

    # Count the number of data points for each category of the specified feature.
    cnt = df_infl.groupby(col)['shap_'].count()

    # Create a dictionary containing the feature, mean SHAP values, standard deviation, and count.
    dd_dict = {'col': list(gain.index), 'gain': list(gain.values), 'gain_std': list(gain_std.values), 'count': cnt}

    # Create a DataFrame from the dictionary and sort it by 'gain' in descending order.
    df_res = pd.DataFrame.from_dict(dd_dict).sort_values('gain', ascending=False).set_index('col')

    # Replace "$" by "*" to use in matplotlib
    if any([('$' in str(idx)) for idx in set(df_res.index)]):
        print('Replacing "$" by "*" to use in matplotlib')
        df_res.index = [c.replace('$','*') for c in df_res.index]

    if df_res['gain'].min() != df_res['gain'].max():
        # Create a plot to visualize the SHAP values with error bars.
        plt.figure(figsize=(9, 6))
        plt.errorbar(df_res.index, df_res['gain'].values, yerr=df_res['gain_std'].values, fmt="o", color="r")

        # Set plot title and axis labels.
        plt.title(f'SHAP values for column {col}, label {label}')
        plt.ylabel(ylabel)
        plt.tick_params(axis="x", rotation=90)

        # Display the plot and the DataFrame with results.
        plt.show()
        print(df_res)

    # Return the function.
    return

# Loop through the columns in the test data.
for col in X_test.columns:
    if col.split('_')[0] not in ['Skills']: # Avoid previously visialised column(s)
        print()  # Print an empty line for better readability.
        print(col)  # Print the name of the current column.
        print()  # Print another empty line for separation.

        # Call the 'show_shap' function to visualize SHAP values for the current column.
        show_shap(col, shap_values, label=main_label, X_test=X_test)
# Out:
# Organization
#                                              gain   gain_std  count
# col
# Google                                      0.0408   0.0090     33
# University of Michigan                      0.0328   0.0143      8
# DeepLearning.AI                             0.0235   0.0084     12
# University of California, Irvine            0.0090   0.0018      5
# University of Illinois at Urbana-Champaign  0.0090   0.0029      7
# Meta                                        0.0061   0.0023      5
# Google Cloud                                0.0037   0.0017     34
# University of Colorado Boulder              0.0007   0.0010      7
# Other                                      -0.0008   0.0023    120
# Duke University                            -0.0109   0.0025      9
# IBM                                        -0.0142   0.0057     35
# University of Pennsylvania                 -0.0362   0.0110     11
# Microsoft                                  -0.0484   0.0088      6
# ...
